# %%
# !pip install requests wikipedia-api sentence-transformers torch pandas nltk notebook
# Out:
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.12/site-packages (2.32.3)
# Requirement already satisfied: wikipedia-api in /opt/anaconda3/lib/python3.12/site-packages (0.8.1)
# Requirement already satisfied: sentence-transformers in /opt/anaconda3/lib/python3.12/site-packages (3.4.1)
# Requirement already satisfied: torch in /opt/anaconda3/lib/python3.12/site-packages (2.6.0)
# Requirement already satisfied: pandas in /opt/anaconda3/lib/python3.12/site-packages (2.2.2)
# Requirement already satisfied: nltk in /opt/anaconda3/lib/python3.12/site-packages (3.9.1)
# Requirement already satisfied: notebook in /opt/anaconda3/lib/python3.12/site-packages (7.2.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2.2.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.12/site-packages (from requests) (2024.8.30)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.49.0)
# Requirement already satisfied: tqdm in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (4.66.5)
# Requirement already satisfied: scikit-learn in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.5.1)
# Requirement already satisfied: scipy in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (1.13.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (0.29.2)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.12/site-packages (from sentence-transformers) (10.4.0)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.13.1)
# Requirement already satisfied: typing-extensions>=4.10.0 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (4.11.0)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.3)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (3.1.4)
# Requirement already satisfied: fsspec in /opt/anaconda3/lib/python3.12/site-packages (from torch) (2024.6.1)
# Requirement already satisfied: setuptools in /opt/anaconda3/lib/python3.12/site-packages (from torch) (75.8.0)
# Requirement already satisfied: sympy==1.13.1 in /opt/anaconda3/lib/python3.12/site-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy>=1.26.0 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/anaconda3/lib/python3.12/site-packages (from pandas) (2023.3)
# Requirement already satisfied: click in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (8.1.7)
# Requirement already satisfied: joblib in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (1.4.2)
# Requirement already satisfied: regex>=2021.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from nltk) (2024.9.11)
# Requirement already satisfied: jupyter-server<3,>=2.4.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook) (2.14.1)
# Requirement already satisfied: jupyterlab-server<3,>=2.27.1 in /opt/anaconda3/lib/python3.12/site-packages (from notebook) (2.27.3)
# Requirement already satisfied: jupyterlab<4.3,>=4.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook) (4.2.5)
# Requirement already satisfied: notebook-shim<0.3,>=0.2 in /opt/anaconda3/lib/python3.12/site-packages (from notebook) (0.2.3)
# Requirement already satisfied: tornado>=6.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from notebook) (6.4.1)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.12/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.1)
# Requirement already satisfied: anyio>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (4.2.0)
# Requirement already satisfied: argon2-cffi>=21.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (21.3.0)
# Requirement already satisfied: jupyter-client>=7.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (8.6.0)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.7.2)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.10.0)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.4.4)
# Requirement already satisfied: nbconvert>=6.4.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.16.4)
# Requirement already satisfied: nbformat>=5.3.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.10.4)
# Requirement already satisfied: overrides>=5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (7.4.0)
# Requirement already satisfied: prometheus-client>=0.9 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.14.1)
# Requirement already satisfied: pyzmq>=24 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (25.1.2)
# Requirement already satisfied: send2trash>=1.8.2 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (0.17.1)
# Requirement already satisfied: traitlets>=5.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (5.14.3)
# Requirement already satisfied: websocket-client>=1.7 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-server<3,>=2.4.0->notebook) (1.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jinja2->torch) (2.1.3)
# Requirement already satisfied: async-lru>=1.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.0.4)
# Requirement already satisfied: httpx>=0.25.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (0.27.0)
# Requirement already satisfied: ipykernel>=6.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (6.28.0)
# Requirement already satisfied: jupyter-lsp>=2.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab<4.3,>=4.2.0->notebook) (2.2.0)
# Requirement already satisfied: babel>=2.10 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (2.11.0)
# Requirement already satisfied: json5>=0.9.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (0.9.6)
# Requirement already satisfied: jsonschema>=4.18.0 in /opt/anaconda3/lib/python3.12/site-packages (from jupyterlab-server<3,>=2.27.1->notebook) (4.23.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.0)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/anaconda3/lib/python3.12/site-packages (from scikit-learn->sentence-transformers) (3.5.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/anaconda3/lib/python3.12/site-packages (from anyio>=3.1.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (21.2.0)
# Requirement already satisfied: httpcore==1.* in /opt/anaconda3/lib/python3.12/site-packages (from httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/anaconda3/lib/python3.12/site-packages (from httpcore==1.*->httpx>=0.25.0->jupyterlab<4.3,>=4.2.0->notebook) (0.14.0)
# Requirement already satisfied: appnope in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.1.3)
# Requirement already satisfied: comm>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.7)
# Requirement already satisfied: ipython>=7.23.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (8.27.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (1.6.0)
# Requirement already satisfied: psutil in /opt/anaconda3/lib/python3.12/site-packages (from ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.9.0)
# Requirement already satisfied: attrs>=22.2.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (23.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema>=4.18.0->jupyterlab-server<3,>=2.27.1->notebook) (0.10.6)
# Requirement already satisfied: platformdirs>=2.5 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-core!=5.0.*,>=4.12->jupyter-server<3,>=2.4.0->notebook) (3.10.0)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/anaconda3/lib/python3.12/site-packages (from jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (0.1.1)
# Requirement already satisfied: beautifulsoup4 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.12.3)
# Requirement already satisfied: bleach!=5.0.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (4.1.0)
# Requirement already satisfied: defusedxml in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.1.2)
# Requirement already satisfied: mistune<4,>=2.0.3 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.0.4)
# Requirement already satisfied: nbclient>=0.5.0 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.8.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.5.0)
# Requirement already satisfied: pygments>=2.4.1 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.15.1)
# Requirement already satisfied: tinycss2 in /opt/anaconda3/lib/python3.12/site-packages (from nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (1.2.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /opt/anaconda3/lib/python3.12/site-packages (from nbformat>=5.3.0->jupyter-server<3,>=2.4.0->notebook) (2.16.2)
# Requirement already satisfied: ptyprocess in /opt/anaconda3/lib/python3.12/site-packages (from terminado>=0.8.3->jupyter-server<3,>=2.4.0->notebook) (0.7.0)
# Requirement already satisfied: webencodings in /opt/anaconda3/lib/python3.12/site-packages (from bleach!=5.0.0->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (0.5.1)
# Requirement already satisfied: decorator in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (3.0.43)
# Requirement already satisfied: stack-data in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/anaconda3/lib/python3.12/site-packages (from ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (4.8.0)
# Requirement already satisfied: fqdn in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.5.1)
# Requirement already satisfied: isoduration in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (2.1)
# Requirement already satisfied: uri-template in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /opt/anaconda3/lib/python3.12/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (24.11.1)
# Requirement already satisfied: cffi>=1.0.1 in /opt/anaconda3/lib/python3.12/site-packages (from argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (1.17.1)
# Requirement already satisfied: soupsieve>1.2 in /opt/anaconda3/lib/python3.12/site-packages (from beautifulsoup4->nbconvert>=6.4.4->jupyter-server<3,>=2.4.0->notebook) (2.5)
# Requirement already satisfied: pycparser in /opt/anaconda3/lib/python3.12/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi>=21.1->jupyter-server<3,>=2.4.0->notebook) (2.21)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/anaconda3/lib/python3.12/site-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.8.3)
# Requirement already satisfied: wcwidth in /opt/anaconda3/lib/python3.12/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.5)
# Requirement already satisfied: arrow>=0.15.0 in /opt/anaconda3/lib/python3.12/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server<3,>=2.4.0->notebook) (1.2.3)
# Requirement already satisfied: executing in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.8.3)
# Requirement already satisfied: asttokens in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (2.0.5)
# Requirement already satisfied: pure-eval in /opt/anaconda3/lib/python3.12/site-packages (from stack-data->ipython>=7.23.1->ipykernel>=6.5.0->jupyterlab<4.3,>=4.2.0->notebook) (0.2.2)
#
# [notice] A new release of pip is available: 25.0 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd

csv_path = "nytcrosswords.csv"
df = pd.read_csv(csv_path, encoding="ISO-8859-1")
df = df[['Clue', 'Word']].dropna()  # Keep only relevant columns
print(f"Dataset Loaded: {len(df)} clues")
# Out:
# Dataset Loaded: 781539 clues

# %%
from sentence_transformers import SentenceTransformer, util
from nltk.corpus import wordnet
import nltk

# Load a pre-trained BERT model
bert_model = SentenceTransformer('all-MiniLM-L6-v2')

# Ensure nltk dependencies are available
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/sheryldeakin/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     /Users/sheryldeakin/nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
def get_synonyms(word):
    """ Get a list of synonyms and related terms for a given word using WordNet. """
    synonyms = set([word])  # Include the original word
    for syn in wordnet.synsets(word):
        for lemma in syn.lemmas():
            clean_word = lemma.name().replace("_", " ")  # Replace underscores with spaces
            synonyms.add(clean_word)
    
    return list(synonyms)

def get_bert_synonyms(word, top_n=10):
    """ Expand words using BERT similarity search. """
    candidate_words = get_synonyms(word)

    if not candidate_words:  # If no synonyms found, return just the original word
        return [word]

    # Compute BERT embeddings for input word
    word_embedding = bert_model.encode(word, convert_to_tensor=True)
    
    # Compute embeddings for candidate words
    candidate_embeddings = bert_model.encode(candidate_words, convert_to_tensor=True)

    # Compute cosine similarity between input word and candidate words
    similarities = util.pytorch_cos_sim(word_embedding, candidate_embeddings)

    top_n = min(top_n, len(candidate_words))  # Adjust `top_n` dynamically
    if top_n == 0:
        return [word]  # If no candidates are found, return the original word
    # Get top N most similar words
    top_indices = torch.topk(similarities, top_n).indices.tolist()[0]
    
    # Return top similar words
    return [candidate_words[i] for i in top_indices]

# %%
def extract_keywords(sentence):
    """ Extract words from the sentence and find their synonyms and related terms. """
    words = re.findall(r'\b\w+\b', sentence)  # Extract words
    expanded_keywords = set()
    for word in words:
        wordnet_synonyms = get_synonyms(word)  # WordNet synonyms
        bert_synonyms = get_bert_synonyms(word)  # BERT synonyms
        expanded_keywords.update(wordnet_synonyms + bert_synonyms)  # Merge both
    return list(expanded_keywords), words  # Return both expanded keywords and original words

# %%
def search_wikipedia_articles(keywords, original_words):
    """ 
    Search Wikipedia for articles containing the keywords.
    """
    wiki = wikipediaapi.Wikipedia(
        user_agent="Project/1.0 (contact: your-email@example.com)",  # Replace with your details
        language="en"
    )
    results = {}

    # Use multiple keywords together for better search results
    search_query = " ".join(keywords[:10])  # Use up to 10 keywords for broader search

    search_url = f"https://en.wikipedia.org/w/api.php?action=query&list=search&srsearch={search_query}&srlimit=50&format=json"
    response = requests.get(search_url, headers={"User-Agent": "MindStormBot/1.0 (contact: deakin.s@northeastern.edu)"}, timeout=30) 
    
    if response.status_code == 200:
        data = response.json()
        search_results = data.get("query", {}).get("search", [])
        for entry in search_results:
            page_title = entry["title"]

            # Exclude pages where the title is an EXACT match to an original input word
            if any(word.lower() == page_title.lower() for word in original_words):
                continue

            page = wiki.page(page_title)
            if page.exists():
                page_text = page.text.lower()

                # Ensure at least one original word or synonym appears
                word_matches = [word.lower() in page_text for word in original_words]
                if sum(word_matches) >= 1:  # Allow pages with at least one match
                    results[page_title] = page.text  # Store relevant pages

    else:
        print(f"Error fetching Wikipedia results for query: {search_query}")

    return results

# %%
def merge_results(expanded_results, original_results):
    """ Merge two result dictionaries, avoiding duplicates. """
    combined_results = {**expanded_results, **original_results}  # Merge without duplicates
    return combined_results

# %%
def count_word_frequencies(text, keywords):
    """ Count occurrences of keywords (words & synonyms) in Wikipedia text. """
    words = re.findall(r'\b\w+\b', text.lower())  # Tokenize Wikipedia text
    word_counts = Counter(words)
    return {word: word_counts[word.lower()] for word in keywords if word.lower() in word_counts}

# %%
def test_wikipedia_search_all(output_file="wikipedia_search_results_full.csv", batch_size=1000):
    """ 
    Test Wikipedia search on all crossword clues.
    Saves results in batches to avoid losing progress.
    """
    
    results = []  # Store evaluation results
    total_clues = len(df)

    for index, row in df.iterrows():
        clue = row["Clue"]
        answer = row["Word"].strip().lower()  # Normalize the answer

        print(f"\n🔍 ({index+1}/{total_clues}) Searching Wikipedia for: {clue} (Expected answer: {answer})")
        
        # Extract keywords using BERT and WordNet
        keywords, original_words = extract_keywords(clue)
        
        # Perform Wikipedia search
        expanded_results = search_wikipedia_articles(keywords, original_words)
        original_results = search_wikipedia_articles(original_words, original_words)

        # Merge results
        wiki_results = merge_results(expanded_results, original_results)

        # Initialize match conditions
        title_match = False
        content_match = False
        matched_page_title = "No Title Match"  # Default title if no match

        # Check if the answer appears in the Wikipedia page **title** or **content**
        for page_title, page_text in wiki_results.items():
            if answer in page_title.lower():  
                title_match = True  # Answer found in title
                matched_page_title = page_title  # Store the matching title
            
            if answer in page_text.lower():
                content_match = True  # Answer found in Wikipedia content
                
                # If no title match, update the matched page title with content match
                if not title_match:
                    matched_page_title = page_title  

            # Stop early if both conditions are met
            if title_match and content_match:
                break  
        
        # Store the result
        results.append({
            "Clue": clue,
            "Expected Answer": answer,
            "Wikipedia Page Title": matched_page_title,  # Store title if found in content
            "Title Match": title_match,
            "Content Match": content_match
        })

        # Save every `batch_size` samples to prevent data loss
        if (index + 1) % batch_size == 0:
            temp_df = pd.DataFrame(results)
            temp_df.to_csv(output_file, index=False, encoding="utf-8")
            print(f"✅ Progress saved: {index + 1}/{total_clues} clues processed.")

    # Final save
    final_df = pd.DataFrame(results)
    final_df.to_csv(output_file, index=False, encoding="utf-8")
    print(f"\n📁 Final results saved to: {output_file}")

    # Display the results in Jupyter Notebook
    import ace_tools as tools
    tools.display_dataframe_to_user(name="Wikipedia Search Results", dataframe=final_df)

# %%
import re
import torch
import requests
import wikipediaapi
import pandas as pd

test_wikipedia_search_all(output_file="nyt_crossword_wiki_results.csv")
# Out:
# 🔍 (1/781539) Searching Wikipedia for: Action done while saying "Good dog" (Expected answer: pat)
#
# 🔍 (2/781539) Searching Wikipedia for: Mischief-makers (Expected answer: rascals)
#
# 🔍 (3/781539) Searching Wikipedia for: It might click for a writer (Expected answer: pen)
#
# 🔍 (4/781539) Searching Wikipedia for: Fall mo. (Expected answer: sep)
#
# 🔍 (5/781539) Searching Wikipedia for: Kind to Mother Nature (Expected answer: eco)
#
# 🔍 (6/781539) Searching Wikipedia for: Harris in the Country Music Hall of Fame (Expected answer: emmylou)
#
# 🔍 (7/781539) Searching Wikipedia for: Living ___ (Expected answer: wage)
#
# 🔍 (8/781539) Searching Wikipedia for: Member of the superfamily Hominoidea (Expected answer: ape)
#
# 🔍 (9/781539) Searching Wikipedia for: Haphazard (Expected answer: hitormiss)
#
# 🔍 (10/781539) Searching Wikipedia for: Some crumbly blocks (Expected answer: feta)
#
# 🔍 (11/781539) Searching Wikipedia for: Inits. for a theatrical hit (Expected answer: sro)
#
# 🔍 (12/781539) Searching Wikipedia for: Send away, in a way (Expected answer: deport)
#
# 🔍 (13/781539) Searching Wikipedia for: Accomplished the task (Expected answer: didit)
#
# 🔍 (14/781539) Searching Wikipedia for: What wiggly lines in comics may represent (Expected answer: odors)
#
# 🔍 (15/781539) Searching Wikipedia for: Cause of boom and bust? (Expected answer: tnt)
#
# 🔍 (16/781539) Searching Wikipedia for: Convene for another session (Expected answer: remeet)
#
# 🔍 (17/781539) Searching Wikipedia for: Up to it (Expected answer: able)
#
# 🔍 (18/781539) Searching Wikipedia for: What's frequently used by poets? (Expected answer: oft)
#
# 🔍 (19/781539) Searching Wikipedia for: "To quote yours truly ..." (Expected answer: asisay)
#
# 🔍 (20/781539) Searching Wikipedia for: ___ dish (Expected answer: petri)
#
# 🔍 (21/781539) Searching Wikipedia for: Heath (Expected answer: moor)
#
# 🔍 (22/781539) Searching Wikipedia for: Desperate (Expected answer: doordie)
#
# 🔍 (23/781539) Searching Wikipedia for: Tries for a role (Expected answer: reads)
#
# 🔍 (24/781539) Searching Wikipedia for: S.F. metro (Expected answer: muni)
#
# 🔍 (25/781539) Searching Wikipedia for: "Hey ... over here!" (Expected answer: psst)
#
# 🔍 (26/781539) Searching Wikipedia for: Derby lengths (Expected answer: metres)
#
# 🔍 (27/781539) Searching Wikipedia for: Equivalent of the Face With Tears of Joy emoji (Expected answer: lol)
#
# 🔍 (28/781539) Searching Wikipedia for: Give a buzz (Expected answer: thrill)
#
# 🔍 (29/781539) Searching Wikipedia for: Inconvenience (Expected answer: imposeon)
#
# 🔍 (30/781539) Searching Wikipedia for: Execute, as a royal of old (Expected answer: behead)
#
# 🔍 (31/781539) Searching Wikipedia for: Classic concert chambers (Expected answer: odea)
#
# 🔍 (32/781539) Searching Wikipedia for: Noted U.S. rock group? (Expected answer: mountrushmore)
#
# 🔍 (33/781539) Searching Wikipedia for: Approximately (Expected answer: moreorless)
#
# 🔍 (34/781539) Searching Wikipedia for: See captain? (Expected answer: pope)
#
# 🔍 (35/781539) Searching Wikipedia for: Studio fixtures (Expected answer: easels)
#
# 🔍 (36/781539) Searching Wikipedia for: State of equilibrium (Expected answer: stasis)
#
# 🔍 (37/781539) Searching Wikipedia for: Code-cracking grp. (Expected answer: nsa)
#
# 🔍 (38/781539) Searching Wikipedia for: Match-ending rugby call (Expected answer: noside)
#
# 🔍 (39/781539) Searching Wikipedia for: Bygone sovereign (Expected answer: shah)
#
# 🔍 (40/781539) Searching Wikipedia for: Dance-a-___ (Expected answer: thon)
#
# 🔍 (41/781539) Searching Wikipedia for: Build on (Expected answer: addto)
#
# 🔍 (42/781539) Searching Wikipedia for: Military dismissal (Expected answer: marchingorders)
#
# 🔍 (43/781539) Searching Wikipedia for: "You game?" (Expected answer: inorout)
#
# 🔍 (44/781539) Searching Wikipedia for: State to be the case (Expected answer: aver)
#
# 🔍 (45/781539) Searching Wikipedia for: ___ Kornfeld, music promoter for Woodstock (Expected answer: artie)
#
# 🔍 (46/781539) Searching Wikipedia for: Daddy-o (Expected answer: hepcat)
#
# 🔍 (47/781539) Searching Wikipedia for: Great Basin native (Expected answer: ute)
#
# 🔍 (48/781539) Searching Wikipedia for: Stun (Expected answer: daze)
#
# 🔍 (49/781539) Searching Wikipedia for: Heavy weights in Britain (Expected answer: tonnes)
#
# 🔍 (50/781539) Searching Wikipedia for: "Murder, ___ Wrote" (Expected answer: she)
#
# 🔍 (51/781539) Searching Wikipedia for: Samuel ___, business partner of Marcus Goldman (Expected answer: sachs)
#
# 🔍 (52/781539) Searching Wikipedia for: Gradually wear away (Expected answer: erode)
#
# 🔍 (53/781539) Searching Wikipedia for: Lipton competitor (Expected answer: nestea)
#
# 🔍 (54/781539) Searching Wikipedia for: Keypad triplet (Expected answer: abc)
#
# 🔍 (55/781539) Searching Wikipedia for: Critical remark (Expected answer: shot)
#
# 🔍 (56/781539) Searching Wikipedia for: Regardless of the outcome (Expected answer: winorlose)
#
# 🔍 (57/781539) Searching Wikipedia for: Card in a royal flush (Expected answer: ace)
#
# 🔍 (58/781539) Searching Wikipedia for: Purposes (Expected answer: aims)
#
# 🔍 (59/781539) Searching Wikipedia for: One runs from Me. to Fla. (Expected answer: usroute)
#
# 🔍 (60/781539) Searching Wikipedia for: Seminoles' sch. (Expected answer: fsu)
#
# 🔍 (61/781539) Searching Wikipedia for: "You betcha!" (Expected answer: yes)
#
# 🔍 (62/781539) Searching Wikipedia for: Northern ___ (curiously named apple variety) (Expected answer: spy)
#
# 🔍 (63/781539) Searching Wikipedia for: Have (Expected answer: possess)
#
# 🔍 (64/781539) Searching Wikipedia for: Boggy expanse (Expected answer: fen)
#
# 🔍 (65/781539) Searching Wikipedia for: Mano a mano (Expected answer: toetotoe)
#
# 🔍 (66/781539) Searching Wikipedia for: Negligent (Expected answer: remiss)
#
# 🔍 (67/781539) Searching Wikipedia for: Silicon Valley's ___ Research Center (Expected answer: ames)
#
# 🔍 (68/781539) Searching Wikipedia for: Candy bit that comes in a plastic roll (Expected answer: smartie)
#
# 🔍 (69/781539) Searching Wikipedia for: Clerical vestment (Expected answer: alb)
#
# 🔍 (70/781539) Searching Wikipedia for: F, in music (Expected answer: loud)
#
# 🔍 (71/781539) Searching Wikipedia for: Southern region of Mesopotamia (Expected answer: sumer)
#
# 🔍 (72/781539) Searching Wikipedia for: Fabric options (Expected answer: patterns)
#
# 🔍 (73/781539) Searching Wikipedia for: Sense of self (Expected answer: ego)
#
# 🔍 (74/781539) Searching Wikipedia for: Fluent speaker of Elvish, say (Expected answer: nerd)
#
# 🔍 (75/781539) Searching Wikipedia for: &epsilon; (Expected answer: epsilon)
#
# 🔍 (76/781539) Searching Wikipedia for: Bugs (Expected answer: pesters)
#
# 🔍 (77/781539) Searching Wikipedia for: Relative of a bug (Expected answer: wiretap)
#
# 🔍 (78/781539) Searching Wikipedia for: Churchill ___ Rooms (London tourist attraction) (Expected answer: war)
#
# 🔍 (79/781539) Searching Wikipedia for: Long ball (Expected answer: homer)
#
# 🔍 (80/781539) Searching Wikipedia for: City with a Little Havana (Expected answer: miami)
#
# 🔍 (81/781539) Searching Wikipedia for: Nickname for José (Expected answer: pepe)
#
# 🔍 (82/781539) Searching Wikipedia for: Farthest down? (Expected answer: saddest)
#
# 🔍 (83/781539) Searching Wikipedia for: Anklebone (Expected answer: talus)
#
# 🔍 (84/781539) Searching Wikipedia for: Least messy (Expected answer: tidiest)
#
# 🔍 (85/781539) Searching Wikipedia for: Sorority member (Expected answer: sister)
#
# 🔍 (86/781539) Searching Wikipedia for: Yang's counterpart (Expected answer: yin)
#
# 🔍 (87/781539) Searching Wikipedia for: "I Wanna Be Sedated" band (Expected answer: ramones)
#
# 🔍 (88/781539) Searching Wikipedia for: Horrid (Expected answer: vile)
#
# 🔍 (89/781539) Searching Wikipedia for: Maximum degree (Expected answer: nth)
#
# 🔍 (90/781539) Searching Wikipedia for: The brainy bunch? (Expected answer: mensa)
#
# 🔍 (91/781539) Searching Wikipedia for: Profligate sort (Expected answer: roue)
#
# 🔍 (92/781539) Searching Wikipedia for: Measures of electrical resistance (Expected answer: ohms)
#
# 🔍 (93/781539) Searching Wikipedia for: One of the fire signs (Expected answer: leo)
#
# 🔍 (94/781539) Searching Wikipedia for: Alveolar trill, as it's commonly known (Expected answer: rolledr)
#
# 🔍 (95/781539) Searching Wikipedia for: Concept, in Cannes (Expected answer: idee)
#
# 🔍 (96/781539) Searching Wikipedia for: Just in case (Expected answer: lest)
#
# 🔍 (97/781539) Searching Wikipedia for: Glasgow gal (Expected answer: lass)
#
# 🔍 (98/781539) Searching Wikipedia for: Mischief-makers (Expected answer: imps)
#
# 🔍 (99/781539) Searching Wikipedia for: ___ court (Expected answer: moot)
#
# 🔍 (100/781539) Searching Wikipedia for: Stage between larva and imago (Expected answer: pupa)
#
# 🔍 (101/781539) Searching Wikipedia for: Consecrates (Expected answer: blesses)
#
# 🔍 (102/781539) Searching Wikipedia for: Act investigated by an insurance company (Expected answer: arson)
#
# 🔍 (103/781539) Searching Wikipedia for: ___ ex machina (Expected answer: deus)
#
# 🔍 (104/781539) Searching Wikipedia for: QVC alternative (Expected answer: hsn)
#
# 🔍 (105/781539) Searching Wikipedia for: Journalist Fallaci who wrote "Interview With History" (Expected answer: oriana)
#
# 🔍 (106/781539) Searching Wikipedia for: Running behind (Expected answer: late)
#
# 🔍 (107/781539) Searching Wikipedia for: Kinda (Expected answer: ish)
#
# 🔍 (108/781539) Searching Wikipedia for: Berate blisteringly (Expected answer: shoutat)
#
# 🔍 (109/781539) Searching Wikipedia for: They can be wrinkled or thumbed (Expected answer: noses)
#
# 🔍 (110/781539) Searching Wikipedia for: Field that deals with fields (Expected answer: agronomy)
#
# 🔍 (111/781539) Searching Wikipedia for: The newest trend, in slang (Expected answer: hotness)
#
# 🔍 (112/781539) Searching Wikipedia for: Inits. at Westminster (Expected answer: hrh)
#
# 🔍 (113/781539) Searching Wikipedia for: Trigger (Expected answer: touchoff)
#
# 🔍 (114/781539) Searching Wikipedia for: Head for the hills? (Expected answer: outhouse)
#
# 🔍 (115/781539) Searching Wikipedia for: Cupidity (Expected answer: avarice)
#
# 🔍 (116/781539) Searching Wikipedia for: Changes from commercial to residential, perhaps (Expected answer: rezones)
#
# 🔍 (117/781539) Searching Wikipedia for: Words to live by (Expected answer: credo)
#
# 🔍 (118/781539) Searching Wikipedia for: Wash out (Expected answer: rinse)
#
# 🔍 (119/781539) Searching Wikipedia for: Popular tick repellent (Expected answer: deet)
#
# 🔍 (120/781539) Searching Wikipedia for: Piercing eye hue (Expected answer: iceblue)
#
# 🔍 (121/781539) Searching Wikipedia for: Trial (Expected answer: testrun)
#
# 🔍 (122/781539) Searching Wikipedia for: ___ of Alexandria (wonder of the ancient world) (Expected answer: pharos)
#
# 🔍 (123/781539) Searching Wikipedia for: Clinch (Expected answer: sewup)
#
# 🔍 (124/781539) Searching Wikipedia for: Puerto Rico clock setting: Abbr. (Expected answer: ast)
#
# 🔍 (125/781539) Searching Wikipedia for: Ballpark figures, in brief (Expected answer: eras)
#
# 🔍 (126/781539) Searching Wikipedia for: Semiserious "Got it!" (Expected answer: ahso)
#
# 🔍 (127/781539) Searching Wikipedia for: Places hangers hang (Expected answer: closets)
#
# 🔍 (128/781539) Searching Wikipedia for: Guff (Expected answer: lip)
#
# 🔍 (129/781539) Searching Wikipedia for: Distributor of CARES Act funds (Expected answer: irs)
#
# 🔍 (130/781539) Searching Wikipedia for: ___ Moines (Expected answer: des)
#
# 🔍 (131/781539) Searching Wikipedia for: Words on some flashcards, informally (Expected answer: vocab)
#
# 🔍 (132/781539) Searching Wikipedia for: Stuff (Expected answer: sate)
#
# 🔍 (133/781539) Searching Wikipedia for: "___ are ..." (Expected answer: odds)
#
# 🔍 (134/781539) Searching Wikipedia for: Academia, it's said (Expected answer: ivorytower)
#
# 🔍 (135/781539) Searching Wikipedia for: TV host who was the subject of the documentary "You Laugh but It's True" (Expected answer: noah)
#
# 🔍 (136/781539) Searching Wikipedia for: Pot price (Expected answer: ante)
#
# 🔍 (137/781539) Searching Wikipedia for: Its larva is eaten as a delicacy in the Mexican dish escamoles (Expected answer: ant)
#
# 🔍 (138/781539) Searching Wikipedia for: Suffix with carboxyl (Expected answer: ase)
#
# 🔍 (139/781539) Searching Wikipedia for: Loved, on social media (Expected answer: hearted)
#
# 🔍 (140/781539) Searching Wikipedia for: "Olympus ___ Fallen" (2013 film) (Expected answer: has)
#
# 🔍 (141/781539) Searching Wikipedia for: Quiet (down) (Expected answer: pipe)
#
# 🔍 (142/781539) Searching Wikipedia for: Defeated, in a way (Expected answer: slain)
#
# 🔍 (143/781539) Searching Wikipedia for: What Real Madrid and F.C. Barcelona play in (Expected answer: laliga)
#
# 🔍 (144/781539) Searching Wikipedia for: Clerical garment (Expected answer: alb)
#
# 🔍 (145/781539) Searching Wikipedia for: Many take notes using one (Expected answer: atm)
#
# 🔍 (146/781539) Searching Wikipedia for: Milk purchase: Abbr. (Expected answer: gal)
#
# 🔍 (147/781539) Searching Wikipedia for: "___ love is better than high birth to me": Shak. (Expected answer: thy)
#
# 🔍 (148/781539) Searching Wikipedia for: Lacking focus (Expected answer: blurry)
#
# 🔍 (149/781539) Searching Wikipedia for: Low-lying areas? (Expected answer: hideouts)
#
# 🔍 (150/781539) Searching Wikipedia for: City name on both the East and West Coast (Expected answer: salem)
#
# 🔍 (151/781539) Searching Wikipedia for: Elwes of "The Princess Bride" (Expected answer: cary)
#
# 🔍 (152/781539) Searching Wikipedia for: Letters that further extend letters (Expected answer: pps)
#
# 🔍 (153/781539) Searching Wikipedia for: You can't leave home with it (Expected answer: baseballbat)
#
# 🔍 (154/781539) Searching Wikipedia for: One who likes to dish? (Expected answer: caterer)
#
# 🔍 (155/781539) Searching Wikipedia for: Ohio congressman Ryan (Expected answer: tim)
#
# 🔍 (156/781539) Searching Wikipedia for: Corn's place (Expected answer: toe)
#
# 🔍 (157/781539) Searching Wikipedia for: Princess ___ Martell on "Game of Thrones" (Expected answer: elia)
#
# 🔍 (158/781539) Searching Wikipedia for: Refrigerate (Expected answer: cool)
#
# 🔍 (159/781539) Searching Wikipedia for: Locale for athletic competition (Expected answer: fieldhouse)
#
# 🔍 (160/781539) Searching Wikipedia for: A long, long time (Expected answer: eons)
#
# 🔍 (161/781539) Searching Wikipedia for: Something that may be broken in a kitchen (Expected answer: yolk)
#
# 🔍 (162/781539) Searching Wikipedia for: Reveal (Expected answer: leton)
#
# 🔍 (163/781539) Searching Wikipedia for: Checked item for some travelers (Expected answer: visa)
#
# 🔍 (164/781539) Searching Wikipedia for: ___-ready (Expected answer: oven)
#
# 🔍 (165/781539) Searching Wikipedia for: Outer layer (Expected answer: coat)
#
# 🔍 (166/781539) Searching Wikipedia for: Linocuts and such (Expected answer: art)
#
# 🔍 (167/781539) Searching Wikipedia for: Without a doubt (Expected answer: byfar)
#
# 🔍 (168/781539) Searching Wikipedia for: ___ Together (punny name for a hardware store) (Expected answer: awl)
#
# 🔍 (169/781539) Searching Wikipedia for: Snickers piece? (Expected answer: teehee)
#
# 🔍 (170/781539) Searching Wikipedia for: Didn't do the right thing (Expected answer: erred)
#
# 🔍 (171/781539) Searching Wikipedia for: Hot (Expected answer: onaroll)
#
# 🔍 (172/781539) Searching Wikipedia for: Get rid of (Expected answer: shed)
#
# 🔍 (173/781539) Searching Wikipedia for: "Alas!" (Expected answer: tisapity)
#
# 🔍 (174/781539) Searching Wikipedia for: Commercial success (Expected answer: adsale)
#
# 🔍 (175/781539) Searching Wikipedia for: One of 768 in a 35-Across: Abbr. (Expected answer: tsp)
#
# 🔍 (176/781539) Searching Wikipedia for: Overseas rate: Abbr. (Expected answer: kph)
#
# 🔍 (177/781539) Searching Wikipedia for: Commotion (Expected answer: hullabaloo)
#
# 🔍 (178/781539) Searching Wikipedia for: Count against? (Expected answer: nays)
#
# 🔍 (179/781539) Searching Wikipedia for: Screening sites (Expected answer: labs)
#
# 🔍 (180/781539) Searching Wikipedia for: One whose work is always cropping up? (Expected answer: farmer)
#
# 🔍 (181/781539) Searching Wikipedia for: Loser to "The Shape of Water" for Best Picture (Expected answer: ladybird)
#
# 🔍 (182/781539) Searching Wikipedia for: Some slumber party activity (Expected answer: girltalk)
#
# 🔍 (183/781539) Searching Wikipedia for: Caulks, e.g. (Expected answer: reseals)
#
# 🔍 (184/781539) Searching Wikipedia for: A.I. on Discovery One (Expected answer: hal)
#
# 🔍 (185/781539) Searching Wikipedia for: Go (for) (Expected answer: opt)
#
# 🔍 (186/781539) Searching Wikipedia for: Vigorous exercise (Expected answer: cardio)
#
# 🔍 (187/781539) Searching Wikipedia for: Substantial (Expected answer: beefy)
#
# 🔍 (188/781539) Searching Wikipedia for: Titular Menotti opera character (Expected answer: amahl)
#
# 🔍 (189/781539) Searching Wikipedia for: Singer Peniston with the 1991 top 5 hit "Finally" (Expected answer: cece)
#
# 🔍 (190/781539) Searching Wikipedia for: Opposite of relaxed (Expected answer: taut)
#
# 🔍 (191/781539) Searching Wikipedia for: Thereabouts (Expected answer: orso)
#
# 🔍 (192/781539) Searching Wikipedia for: ___ Prairie, suburb of Minneapolis (Expected answer: eden)
#
# 🔍 (193/781539) Searching Wikipedia for: It's hair-raising (Expected answer: gel)
#
# 🔍 (194/781539) Searching Wikipedia for: Wretchedness (Expected answer: woe)
#
# 🔍 (195/781539) Searching Wikipedia for: Rhyming ice cream treat (Expected answer: chocotaco)
#
# 🔍 (196/781539) Searching Wikipedia for: They may be loaded or covered (Expected answer: bases)
#
# 🔍 (197/781539) Searching Wikipedia for: If you ask her to make you a sandwich, she'll say "OK, you're a sandwich" (Expected answer: alexa)
#
# 🔍 (198/781539) Searching Wikipedia for: Foolish in an endearing way (Expected answer: dippy)
#
# 🔍 (199/781539) Searching Wikipedia for: Summer setting in the Windy City (Expected answer: cdt)
#
# 🔍 (200/781539) Searching Wikipedia for: Ten C-notes (Expected answer: oneg)
#
# 🔍 (201/781539) Searching Wikipedia for: Bachelorette party accessories (Expected answer: sashes)
#
# 🔍 (202/781539) Searching Wikipedia for: One in the Jenner family (Expected answer: kris)
#
# 🔍 (203/781539) Searching Wikipedia for: High rollers' rollers (Expected answer: limos)
#
# 🔍 (204/781539) Searching Wikipedia for: Some world leaders (Expected answer: emirs)
#
# 🔍 (205/781539) Searching Wikipedia for: Way to go: Abbr. (Expected answer: rte)
#
# 🔍 (206/781539) Searching Wikipedia for: Absolved (Expected answer: exempt)
#
# 🔍 (207/781539) Searching Wikipedia for: French word that sounds like a letter of the alphabet (Expected answer: eau)
#
# 🔍 (208/781539) Searching Wikipedia for: Ask "Why should I?," say (Expected answer: sass)
#
# 🔍 (209/781539) Searching Wikipedia for: Vote by ___ (Expected answer: mail)
#
# 🔍 (210/781539) Searching Wikipedia for: Org. involving course work (Expected answer: lpga)
#
# 🔍 (211/781539) Searching Wikipedia for: Dept. store stock (Expected answer: mdse)
#
# 🔍 (212/781539) Searching Wikipedia for: Neighbor of Caps Lock (Expected answer: tab)
#
# 🔍 (213/781539) Searching Wikipedia for: N.B.A. team coached in the '70s by Bill Russell (Expected answer: sonics)
#
# 🔍 (214/781539) Searching Wikipedia for: Sea eagle (Expected answer: ern)
#
# 🔍 (215/781539) Searching Wikipedia for: [More worms, mama!] (Expected answer: chirp)
#
# 🔍 (216/781539) Searching Wikipedia for: Easy-peasy (Expected answer: asnap)
#
# 🔍 (217/781539) Searching Wikipedia for: Hairstyle for 2-Down (Expected answer: afro)
#
# 🔍 (218/781539) Searching Wikipedia for: Tight (with) (Expected answer: ingood)
#
# 🔍 (219/781539) Searching Wikipedia for: Certain blood vessel, to a physician (Expected answer: vena)
#
# 🔍 (220/781539) Searching Wikipedia for: ___ Burgundy, Will Ferrell persona (Expected answer: ron)
#
# 🔍 (221/781539) Searching Wikipedia for: Shield adorned with Medusa's head (Expected answer: aegis)
#
# 🔍 (222/781539) Searching Wikipedia for: Ginormous (Expected answer: humongous)
#
# 🔍 (223/781539) Searching Wikipedia for: Static, e.g. (Expected answer: noise)
#
# 🔍 (224/781539) Searching Wikipedia for: Twisted look (Expected answer: sneer)
#
# 🔍 (225/781539) Searching Wikipedia for: Lewis Carroll character who asks "Does your watch tell you what year it is?" (Expected answer: madhatter)
#
# 🔍 (226/781539) Searching Wikipedia for: Woodstock headliner (Expected answer: hendrix)
#
# 🔍 (227/781539) Searching Wikipedia for: Bygone (Expected answer: oldtime)
#
# 🔍 (228/781539) Searching Wikipedia for: The Browns, on scoreboards (Expected answer: cle)
#
# 🔍 (229/781539) Searching Wikipedia for: Oaxacan "other" (Expected answer: otro)
#
# 🔍 (230/781539) Searching Wikipedia for: Burgs (Expected answer: towns)
#
# 🔍 (231/781539) Searching Wikipedia for: Individually (Expected answer: apiece)
#
# 🔍 (232/781539) Searching Wikipedia for: Spanish "Hey!" (Expected answer: oye)
#
# 🔍 (233/781539) Searching Wikipedia for: Fierce (Expected answer: badass)
#
# 🔍 (234/781539) Searching Wikipedia for: Most desirable, as guests (Expected answer: alist)
#
# 🔍 (235/781539) Searching Wikipedia for: Ulta competitor (Expected answer: sephora)
#
# 🔍 (236/781539) Searching Wikipedia for: Whizzes (Expected answer: experts)
#
# 🔍 (237/781539) Searching Wikipedia for: Accepts a ring, perhaps (Expected answer: saysyes)
#
# 🔍 (238/781539) Searching Wikipedia for: Ice cream shop supplies (Expected answer: syrups)
#
# 🔍 (239/781539) Searching Wikipedia for: River in Picardy (Expected answer: somme)
#
# 🔍 (240/781539) Searching Wikipedia for: Yemeni money (Expected answer: rial)
#
# 🔍 (241/781539) Searching Wikipedia for: Facial spot (Expected answer: spa)
#
# 🔍 (242/781539) Searching Wikipedia for: Gave faithfully, in a way (Expected answer: tithed)
#
# 🔍 (243/781539) Searching Wikipedia for: ___ Stark, role for which Sophie Turner was Emmy-nominated (Expected answer: sansa)
#
# 🔍 (244/781539) Searching Wikipedia for: Put down (Expected answer: laid)
#
# 🔍 (245/781539) Searching Wikipedia for: ___ step further (Expected answer: goa)
#
# 🔍 (246/781539) Searching Wikipedia for: Traffic dividers (Expected answer: medians)
#
# 🔍 (247/781539) Searching Wikipedia for: Talk long and boringly (Expected answer: droneon)
#
# 🔍 (248/781539) Searching Wikipedia for: Virtuosa's display (Expected answer: bravura)
#
# 🔍 (249/781539) Searching Wikipedia for: Short person's group photo position, ideally (Expected answer: infront)
#
# 🔍 (250/781539) Searching Wikipedia for: Go barhopping, say (Expected answer: carouse)
#
# 🔍 (251/781539) Searching Wikipedia for: Name on many a sports jersey (Expected answer: sponsor)
#
# 🔍 (252/781539) Searching Wikipedia for: Dealmaking pro (Expected answer: closer)
#
# 🔍 (253/781539) Searching Wikipedia for: Taking a heavy science course load, perhaps (Expected answer: premed)
#
# 🔍 (254/781539) Searching Wikipedia for: Capital near the old Oregon Trail (Expected answer: boise)
#
# 🔍 (255/781539) Searching Wikipedia for: Eldest son of Cain (Expected answer: enoch)
#
# 🔍 (256/781539) Searching Wikipedia for: "Puppy Love" singer, 1960 (Expected answer: anka)
#
# 🔍 (257/781539) Searching Wikipedia for: He/___ pronouns (Expected answer: him)
#
# 🔍 (258/781539) Searching Wikipedia for: Caught (Expected answer: got)
#
# 🔍 (259/781539) Searching Wikipedia for: Possible result of a TMZ story (Expected answer: badpr)
#
# 🔍 (260/781539) Searching Wikipedia for: Behind, nautically (Expected answer: abaft)
#
# 🔍 (261/781539) Searching Wikipedia for: "American Dad!" network (Expected answer: tbs)
#
# 🔍 (262/781539) Searching Wikipedia for: Theme of la festa di San Valentino (Expected answer: amore)
#
# 🔍 (263/781539) Searching Wikipedia for: Spanish equivalent of "Basta!" (Expected answer: nomas)
#
# 🔍 (264/781539) Searching Wikipedia for: Word with know or show (Expected answer: how)
#
# 🔍 (265/781539) Searching Wikipedia for: Virtuoso (Expected answer: ace)
#
# 🔍 (266/781539) Searching Wikipedia for: This is only a test (Expected answer: exam)
#
# 🔍 (267/781539) Searching Wikipedia for: Sauce that's 80% vowels (Expected answer: aioli)
#
# 🔍 (268/781539) Searching Wikipedia for: Worshiper at the ancient Qorikancha ("Golden Temple") (Expected answer: inca)
#
# 🔍 (269/781539) Searching Wikipedia for: Core group (Expected answer: abs)
#
# 🔍 (270/781539) Searching Wikipedia for: Ending for some government 37-Across (Expected answer: mil)
#
# 🔍 (271/781539) Searching Wikipedia for: Poker giveaway (Expected answer: tell)
#
# 🔍 (272/781539) Searching Wikipedia for: "Beauty is truth, truth beauty" poet (Expected answer: keats)
#
# 🔍 (273/781539) Searching Wikipedia for: Info in a modern bibliography (Expected answer: urls)
#
# 🔍 (274/781539) Searching Wikipedia for: Gets warmer, so to speak (Expected answer: nears)
#
# 🔍 (275/781539) Searching Wikipedia for: Tackles, say (Expected answer: stat)
#
# 🔍 (276/781539) Searching Wikipedia for: Kind of reform or code (Expected answer: penal)
#
# 🔍 (277/781539) Searching Wikipedia for: "Read the clues carefully" and "Check your crossing answers" [You're welcome!] (Expected answer: tips)
#
# 🔍 (278/781539) Searching Wikipedia for: Big name in nail polish (Expected answer: opi)
#
# 🔍 (279/781539) Searching Wikipedia for: "Abso-lutely not!" (Expected answer: ohgodno)
#
# 🔍 (280/781539) Searching Wikipedia for: Be over (Expected answer: end)
#
# 🔍 (281/781539) Searching Wikipedia for: Broadcast journalist Paula (Expected answer: zahn)
#
# 🔍 (282/781539) Searching Wikipedia for: Purple shade (Expected answer: grape)
#
# 🔍 (283/781539) Searching Wikipedia for: Not do anything (Expected answer: idle)
#
# 🔍 (284/781539) Searching Wikipedia for: ___-Man (Expected answer: ant)
#
# 🔍 (285/781539) Searching Wikipedia for: Landmark 1973 court case, familiarly (Expected answer: roe)
#
# 🔍 (286/781539) Searching Wikipedia for: Sync up (Expected answer: align)
#
# 🔍 (287/781539) Searching Wikipedia for: With 13-Down, playground promise (Expected answer: pinky)
#
# 🔍 (288/781539) Searching Wikipedia for: White wine aperitif (Expected answer: kir)
#
# 🔍 (289/781539) Searching Wikipedia for: Old Apple Store offerings (Expected answer: nanos)
#
# 🔍 (290/781539) Searching Wikipedia for: Ophthalmological ailments (Expected answer: styes)
#
# 🔍 (291/781539) Searching Wikipedia for: Sweets (Expected answer: babe)
#
# 🔍 (292/781539) Searching Wikipedia for: Discover alternative, for short (Expected answer: amex)
#
# 🔍 (293/781539) Searching Wikipedia for: Toon with a talking map (Expected answer: dora)
#
# 🔍 (294/781539) Searching Wikipedia for: Fundamental (Expected answer: primal)
#
# 🔍 (295/781539) Searching Wikipedia for: On the ___ (frequently, in modern slang) (Expected answer: reg)
#
# 🔍 (296/781539) Searching Wikipedia for: Pro's opposite (Expected answer: anti)
#
# 🔍 (297/781539) Searching Wikipedia for: Classic clown name (Expected answer: bobo)
#
# 🔍 (298/781539) Searching Wikipedia for: Picturesque town on the Gulf of Salerno (Expected answer: amalfi)
#
# 🔍 (299/781539) Searching Wikipedia for: Adroit (Expected answer: facile)
#
# 🔍 (300/781539) Searching Wikipedia for: Sound made with one's tongue (Expected answer: tsk)
#
# 🔍 (301/781539) Searching Wikipedia for: Ball game (Expected answer: bocce)
#
# 🔍 (302/781539) Searching Wikipedia for: See 68-Across (Expected answer: swear)
#
# 🔍 (303/781539) Searching Wikipedia for: Expedite (Expected answer: hasten)
#
# 🔍 (304/781539) Searching Wikipedia for: Causes of some brain freezes (Expected answer: icees)
#
# 🔍 (305/781539) Searching Wikipedia for: Sandwich that's 100% consonants (Expected answer: blt)
#
# 🔍 (306/781539) Searching Wikipedia for: "Ugh!" (Expected answer: ick)
#
# 🔍 (307/781539) Searching Wikipedia for: "My turn!" (Expected answer: imup)
#
# 🔍 (308/781539) Searching Wikipedia for: Can (Expected answer: fire)
#
# 🔍 (309/781539) Searching Wikipedia for: Something that may be pulled in college (Expected answer: allnighter)
#
# 🔍 (310/781539) Searching Wikipedia for: "Bravo!" relative (Expected answer: ole)
#
# 🔍 (311/781539) Searching Wikipedia for: Author of the "Symposium" (Expected answer: plato)
#
# 🔍 (312/781539) Searching Wikipedia for: Stick with it! (Expected answer: tape)
#
# 🔍 (313/781539) Searching Wikipedia for: Commotion (Expected answer: stir)
#
# 🔍 (314/781539) Searching Wikipedia for: Suppressed (Expected answer: saton)
#
# 🔍 (315/781539) Searching Wikipedia for: "Spare" item (Expected answer: rib)
#
# 🔍 (316/781539) Searching Wikipedia for: Wild times at the mall, say (Expected answer: sprees)
#
# 🔍 (317/781539) Searching Wikipedia for: What the D.E.A. might keep tabs on? (Expected answer: lsd)
#
# 🔍 (318/781539) Searching Wikipedia for: ___ Ysidro, Calif. (Expected answer: san)
#
# 🔍 (319/781539) Searching Wikipedia for: Bassett of "Black Panther" (Expected answer: angela)
#
# 🔍 (320/781539) Searching Wikipedia for: Ideal picnic forecast (Expected answer: norain)
#
# 🔍 (321/781539) Searching Wikipedia for: "Yay, me!" (Expected answer: ididit)
#
# 🔍 (322/781539) Searching Wikipedia for: Netflix crime drama set in the Midwest (Expected answer: ozark)
#
# 🔍 (323/781539) Searching Wikipedia for: World capital with traditional water puppet shows for tourists (Expected answer: hanoi)
#
# 🔍 (324/781539) Searching Wikipedia for: Preceder of a certain "-naut" (Expected answer: argo)
#
# 🔍 (325/781539) Searching Wikipedia for: Puts on paper (Expected answer: pens)
#
# 🔍 (326/781539) Searching Wikipedia for: Withhold from (Expected answer: deny)
#
# 🔍 (327/781539) Searching Wikipedia for: Canoeing locale (Expected answer: lake)
#
# 🔍 (328/781539) Searching Wikipedia for: Turkey Hill competitor (Expected answer: edys)
#
# 🔍 (329/781539) Searching Wikipedia for: Colorless (Expected answer: wan)
#
# 🔍 (330/781539) Searching Wikipedia for: Photo finish? (Expected answer: ops)
#
# 🔍 (331/781539) Searching Wikipedia for: "The Fox and the Grapes," e.g. (Expected answer: fable)
#
# 🔍 (332/781539) Searching Wikipedia for: What often follows "Did you hear ...?" (Expected answer: rumor)
#
# 🔍 (333/781539) Searching Wikipedia for: ___ Jima (Expected answer: iwo)
#
# 🔍 (334/781539) Searching Wikipedia for: Yet to be rented (Expected answer: unlet)
#
# 🔍 (335/781539) Searching Wikipedia for: Unsuk Chin's "Alice in Wonderland," for one (Expected answer: opera)
#
# 🔍 (336/781539) Searching Wikipedia for: Hosp. scan (Expected answer: mri)
#
# 🔍 (337/781539) Searching Wikipedia for: Buddy (Expected answer: pal)
#
# 🔍 (338/781539) Searching Wikipedia for: Cacophony (Expected answer: din)
#
# 🔍 (339/781539) Searching Wikipedia for: William who lent his name to a state (Expected answer: penn)
#
# 🔍 (340/781539) Searching Wikipedia for: Masterful moves (Expected answer: coups)
#
# 🔍 (341/781539) Searching Wikipedia for: Apple platform (Expected answer: ios)
#
# 🔍 (342/781539) Searching Wikipedia for: Baked ___ (Expected answer: alaska)
#
# 🔍 (343/781539) Searching Wikipedia for: Belief system (Expected answer: credo)
#
# 🔍 (344/781539) Searching Wikipedia for: Womb mate (Expected answer: twin)
#
# 🔍 (345/781539) Searching Wikipedia for: Sue Grafton's "___ for Innocent" (Expected answer: iis)
#
# 🔍 (346/781539) Searching Wikipedia for: Classic opening line from an NBC sketch show (Expected answer: livefromnewyork)
#
# 🔍 (347/781539) Searching Wikipedia for: King or queen topper (Expected answer: ace)
#
# 🔍 (348/781539) Searching Wikipedia for: Baby ___ ("The Mandalorian" nickname) (Expected answer: yoda)
#
# 🔍 (349/781539) Searching Wikipedia for: Looks all over (for) (Expected answer: hunts)
#
# 🔍 (350/781539) Searching Wikipedia for: Reply to "Gracias" (Expected answer: denada)
#
# 🔍 (351/781539) Searching Wikipedia for: "___ Duke" (1976 Stevie Wonder hit) (Expected answer: sir)
#
# 🔍 (352/781539) Searching Wikipedia for: Doughnut go-with on an orchard tour (Expected answer: cider)
#
# 🔍 (353/781539) Searching Wikipedia for: Indian honorifics (Expected answer: sris)
#
# 🔍 (354/781539) Searching Wikipedia for: Little dog's bark (Expected answer: yap)
#
# 🔍 (355/781539) Searching Wikipedia for: "I'll take that as ___" (Expected answer: ano)
#
# 🔍 (356/781539) Searching Wikipedia for: Pot-au-___ (French stew) (Expected answer: feu)
#
# 🔍 (357/781539) Searching Wikipedia for: How some will solve this crossword (Expected answer: inink)
#
# 🔍 (358/781539) Searching Wikipedia for: Start of a playground selection process (Expected answer: eenie)
#
# 🔍 (359/781539) Searching Wikipedia for: Humorous suffix with "most" and "best" (Expected answer: est)
#
# 🔍 (360/781539) Searching Wikipedia for: Religious offshoots (Expected answer: sects)
#
# 🔍 (361/781539) Searching Wikipedia for: Made ewe cry? (Expected answer: baaed)
#
# 🔍 (362/781539) Searching Wikipedia for: "Wabbit" pursuer Elmer (Expected answer: fudd)
#
# 🔍 (363/781539) Searching Wikipedia for: Diarist Nin (Expected answer: anais)
#
# 🔍 (364/781539) Searching Wikipedia for: Mel who voiced 1-Down (Expected answer: blanc)
#
# 🔍 (365/781539) Searching Wikipedia for: Grassy field (Expected answer: lea)
#
# 🔍 (366/781539) Searching Wikipedia for: Greek "H" (Expected answer: eta)
#
# 🔍 (367/781539) Searching Wikipedia for: Dressed like a Supreme Court justice (Expected answer: robed)
#
# 🔍 (368/781539) Searching Wikipedia for: Overturn (Expected answer: upend)
#
# 🔍 (369/781539) Searching Wikipedia for: Ogreish sort (Expected answer: meany)
#
# 🔍 (370/781539) Searching Wikipedia for: Hockey great Bobby (Expected answer: orr)
#
# 🔍 (371/781539) Searching Wikipedia for: Scamp (Expected answer: rascal)
#
# 🔍 (372/781539) Searching Wikipedia for: Some fine art (Expected answer: oils)
#
# 🔍 (373/781539) Searching Wikipedia for: Imitates (Expected answer: apes)
#
# 🔍 (374/781539) Searching Wikipedia for: Humorous suffix with "crap" and "schnozz" (Expected answer: ola)
#
# 🔍 (375/781539) Searching Wikipedia for: Prep for a surprise party, in a way (Expected answer: hide)
#
# 🔍 (376/781539) Searching Wikipedia for: Big dog's bark (Expected answer: woof)
#
# 🔍 (377/781539) Searching Wikipedia for: Nemesis (Expected answer: bane)
#
# 🔍 (378/781539) Searching Wikipedia for: Doesn't just assume, say (Expected answer: asks)
#
# 🔍 (379/781539) Searching Wikipedia for: Attired (Expected answer: clad)
#
# 🔍 (380/781539) Searching Wikipedia for: Made level (Expected answer: evenedout)
#
# 🔍 (381/781539) Searching Wikipedia for: Also (Expected answer: too)
#
# 🔍 (382/781539) Searching Wikipedia for: Subj. of arms talks (Expected answer: wmd)
#
# 🔍 (383/781539) Searching Wikipedia for: ___ funk (Expected answer: ina)
#
# 🔍 (384/781539) Searching Wikipedia for: Hanks's "Sleepless in Seattle" co-star (Expected answer: ryan)
#
# 🔍 (385/781539) Searching Wikipedia for: Sound from a fan (Expected answer: whir)
#
# 🔍 (386/781539) Searching Wikipedia for: Portable structure that's pitched (Expected answer: yurt)
#
# 🔍 (387/781539) Searching Wikipedia for: Exist (Expected answer: are)
#
# 🔍 (388/781539) Searching Wikipedia for: Skin layer (Expected answer: dermis)
#
# 🔍 (389/781539) Searching Wikipedia for: Uninspiring (Expected answer: soso)
#
# 🔍 (390/781539) Searching Wikipedia for: Overseer of Hamlet's duel with Laertes (Expected answer: osric)
#
# 🔍 (391/781539) Searching Wikipedia for: Council site of 1545 (Expected answer: trent)
#
# 🔍 (392/781539) Searching Wikipedia for: Absorbs, as body moisture (Expected answer: wicks)
#
# 🔍 (393/781539) Searching Wikipedia for: "Laughing" scavenger (Expected answer: hyena)
#
# 🔍 (394/781539) Searching Wikipedia for: New Haven Ivy Leaguer (Expected answer: yalie)
#
# 🔍 (395/781539) Searching Wikipedia for: ___ au lait (Expected answer: cafe)
#
# 🔍 (396/781539) Searching Wikipedia for: Begged (Expected answer: pled)
#
# 🔍 (397/781539) Searching Wikipedia for: What the tangent of 45° is equal to (Expected answer: one)
#
# 🔍 (398/781539) Searching Wikipedia for: Something that's catchy? (Expected answer: web)
#
# 🔍 (399/781539) Searching Wikipedia for: Actress Arthur (Expected answer: bea)
#
# 🔍 (400/781539) Searching Wikipedia for: Off-the-cuff remarks (Expected answer: adlibs)
#
# 🔍 (401/781539) Searching Wikipedia for: London TV inits. (Expected answer: bbc)
#
# 🔍 (402/781539) Searching Wikipedia for: Dark wines (Expected answer: reds)
#
# 🔍 (403/781539) Searching Wikipedia for: Place for daisies (Expected answer: meadow)
#
# 🔍 (404/781539) Searching Wikipedia for: Fair-hiring letters (Expected answer: eeo)
#
# 🔍 (405/781539) Searching Wikipedia for: Treat with a 71%-to-29% cookie-to-cream ratio (Expected answer: oreo)
#
# 🔍 (406/781539) Searching Wikipedia for: Microscopic life form (Expected answer: amoeba)
#
# 🔍 (407/781539) Searching Wikipedia for: Looks for web content about oneself (Expected answer: egosurfs)
#
# 🔍 (408/781539) Searching Wikipedia for: "___ Poetica" (Expected answer: ars)
#
# 🔍 (409/781539) Searching Wikipedia for: Connery who played 007 seven times (Expected answer: sean)
#
# 🔍 (410/781539) Searching Wikipedia for: Catbird seat? (Expected answer: perch)
#
# 🔍 (411/781539) Searching Wikipedia for: Crystal ball gazers, e.g. (Expected answer: seers)
#
# 🔍 (412/781539) Searching Wikipedia for: Nobelist Wiesel (Expected answer: elie)
#
# 🔍 (413/781539) Searching Wikipedia for: "Well, what a surprise!" (Expected answer: oho)
#
# 🔍 (414/781539) Searching Wikipedia for: What expensive things cost (Expected answer: anarmandaleg)
#
# 🔍 (415/781539) Searching Wikipedia for: Brings home with a hit, as a base runner (Expected answer: batsin)
#
# 🔍 (416/781539) Searching Wikipedia for: Treble symbols (Expected answer: gclefs)
#
# 🔍 (417/781539) Searching Wikipedia for: Magnet for criticism (Expected answer: lightningrod)
#
# 🔍 (418/781539) Searching Wikipedia for: "What ___, chopped liver?" (Expected answer: ami)
#
# 🔍 (419/781539) Searching Wikipedia for: Vicinity (Expected answer: area)
#
# 🔍 (420/781539) Searching Wikipedia for: Sniffed (around) (Expected answer: nosed)
#
# 🔍 (421/781539) Searching Wikipedia for: Prove appropriate for (Expected answer: befit)
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connection.py:507, in HTTPConnection.getresponse(self)
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#
# File /opt/anaconda3/lib/python3.12/http/client.py:1428, in HTTPConnection.getresponse(self)
#    1427 try:
# -> 1428     response.begin()
#    1429 except ConnectionError:
#
# File /opt/anaconda3/lib/python3.12/http/client.py:331, in HTTPResponse.begin(self)
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#
# File /opt/anaconda3/lib/python3.12/http/client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#
# File /opt/anaconda3/lib/python3.12/socket.py:720, in SocketIO.readinto(self, b)
#     719 try:
# --> 720     return self._sock.recv_into(b)
#     721 except timeout:
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1251, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248         raise ValueError(
#    1249           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1250           self.__class__)
# -> 1251     return self.read(nbytes, buffer)
#    1252 else:
#
# File /opt/anaconda3/lib/python3.12/ssl.py:1103, in SSLSocket.read(self, len, buffer)
#    1102 if buffer is not None:
# -> 1103     return self._sslobj.read(len, buffer)
#    1104 else:
#
# TimeoutError: The read operation timed out
#
# The above exception was the direct cause of the following exception:
#
# ReadTimeoutError                          Traceback (most recent call last)
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:843, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     841     new_e = ProtocolError("Connection aborted.", new_e)
# --> 843 retries = retries.increment(
#     844     method, url, error=new_e, _pool=self, _stacktrace=sys.exc_info()[2]
#     845 )
#     846 retries.sleep()
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/retry.py:474, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     473 if read is False or method is None or not self._is_method_retryable(method):
# --> 474     raise reraise(type(error), error, _stacktrace)
#     475 elif read is not None:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/util/util.py:39, in reraise(tp, value, tb)
#      38         raise value.with_traceback(tb)
# ---> 39     raise value
#      40 finally:
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:538, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     537 except (BaseSSLError, OSError) as e:
# --> 538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#     539     raise
#
# File /opt/anaconda3/lib/python3.12/site-packages/urllib3/connectionpool.py:369, in HTTPConnectionPool._raise_timeout(self, err, url, timeout_value)
#     368 if isinstance(err, SocketTimeout):
# --> 369     raise ReadTimeoutError(
#     370         self, url, f"Read timed out. (read timeout={timeout_value})"
#     371     ) from err
#     373 # See the above comment about EAGAIN in Python 3.
#
# ReadTimeoutError: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Read timed out. (read timeout=10.0)
#
# During handling of the above exception, another exception occurred:
#
# ReadTimeout                               Traceback (most recent call last)
# Cell In[24], line 7
#       4 import wikipediaapi
#       5 import pandas as pd
# ----> 7 test_wikipedia_search_all(output_file="nyt_crossword_wiki_results.csv")
#
# Cell In[20], line 20, in test_wikipedia_search_all(output_file, batch_size)
#      17 keywords, original_words = extract_keywords(clue)
#      19 # Perform Wikipedia search
# ---> 20 expanded_results = search_wikipedia_articles(keywords, original_words)
#      21 original_results = search_wikipedia_articles(original_words, original_words)
#      23 # Merge results
#
# Cell In[15], line 29, in search_wikipedia_articles(keywords, original_words)
#      27 page = wiki.page(page_title)
#      28 if page.exists():
# ---> 29     page_text = page.text.lower()
#      31     # Ensure at least one original word or synonym appears
#      32     word_matches = [word.lower() in page_text for word in original_words]
#
# File /opt/anaconda3/lib/python3.12/site-packages/wikipediaapi/__init__.py:1064, in WikipediaPage.text(self)
#    1057 @property
#    1058 def text(self) -> str:
#    1059     """
#    1060     Returns text of the current page.
#    1061
#    1062     :return: text of the current page
#    1063     """
# -> 1064     txt = self.summary
#    1065     if len(txt) > 0:
#    1066         txt += "\n\n"
#
# File /opt/anaconda3/lib/python3.12/site-packages/wikipediaapi/__init__.py:1009, in WikipediaPage.summary(self)
#    1003 """
#    1004 Returns summary of the current page.
#    1005
#    1006 :return: summary
#    1007 """
#    1008 if not self._called["extracts"]:
# -> 1009     self._fetch("extracts")
#    1010 return self._summary
#
# File /opt/anaconda3/lib/python3.12/site-packages/wikipediaapi/__init__.py:1153, in WikipediaPage._fetch(self, call)
#    1151 def _fetch(self, call) -> "WikipediaPage":
#    1152     """Fetches some data?."""
# -> 1153     getattr(self.wiki, call)(self)
#    1154     self._called[call] = True
#    1155     return self
#
# File /opt/anaconda3/lib/python3.12/site-packages/wikipediaapi/__init__.py:304, in Wikipedia.extracts(self, page, **kwargs)
#     301 used_params = kwargs
#     302 used_params.update(params)
# --> 304 raw = self._query(page, used_params)
#     305 self._common_attributes(raw["query"], page)
#     306 pages = raw["query"]["pages"]
#
# File /opt/anaconda3/lib/python3.12/site-packages/wikipediaapi/__init__.py:539, in Wikipedia._query(self, page, params)
#     530 used_params = self._construct_params(page, params)
#     532 log.info(
#     533     "Request URL: %s",
#     534     base_url
#     535     + "?"
#     536     + "&".join([k + "=" + str(v) for k, v in used_params.items()]),
#     537 )
# --> 539 r = self._session.get(base_url, params=used_params, **self._request_kwargs)
#     540 return r.json()
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:602, in Session.get(self, url, **kwargs)
#     594 r"""Sends a GET request. Returns :class:`Response` object.
#     595
#     596 :param url: URL for the new :class:`Request` object.
#     597 :param \*\*kwargs: Optional arguments that ``request`` takes.
#     598 :rtype: requests.Response
#     599 """
#     601 kwargs.setdefault("allow_redirects", True)
# --> 602 return self.request("GET", url, **kwargs)
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File /opt/anaconda3/lib/python3.12/site-packages/requests/adapters.py:713, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     711     raise SSLError(e, request=request)
#     712 elif isinstance(e, ReadTimeoutError):
# --> 713     raise ReadTimeout(e, request=request)
#     714 elif isinstance(e, _InvalidHeader):
#     715     raise InvalidHeader(e, request=request)
#
# ReadTimeout: HTTPSConnectionPool(host='en.wikipedia.org', port=443): Read timed out. (read timeout=10.0)
